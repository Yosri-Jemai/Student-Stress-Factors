# %% [markdown]
# # Loading the data

# %%
# Importing required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Loading dataset to Notebook via pandas 
data = pd.read_csv("DataSet/StressLevelDataset.csv")
data.head()
# Out:
#    anxiety_level  self_esteem  mental_health_history  depression  headache  \
# 0             14           20                      0          11         2
# 1             15            8                      1          15         5
# 2             12           18                      1          14         2
# 3             16           12                      1          15         4
# 4             16           28                      0           7         2
#
#    blood_pressure  sleep_quality  breathing_problem  noise_level  \
# 0               1              2                  4            2
# 1               3              1                  4            3
# 2               1              2                  2            2
# 3               3              1                  3            4
# 4               3              5                  1            3
#
#    living_conditions  ...  basic_needs  academic_performance  study_load  \
# 0                  3  ...            2                     3           2
# 1                  1  ...            2                     1           4
# 2                  2  ...            2                     2           3
# 3                  2  ...            2                     2           4
# 4                  2  ...            3                     4           3
#
#    teacher_student_relationship  future_career_concerns  social_support  \
# 0                             3                       3               2
# 1                             1                       5               1
# 2                             3                       2               2
# 3                             1                       4               1
# 4                             1                       2               1
#
#    peer_pressure  extracurricular_activities  bullying  stress_level
# 0              3                           3         2             1
# 1              4                           5         5             2
# 2              3                           2         2             1
# 3              4                           4         5             2
# 4              5                           0         5             1
#
# [5 rows x 21 columns]

# %%
# Basic information about df like  How many students are in the dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1100 entries, 0 to 1099
# Data columns (total 21 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   anxiety_level                 1100 non-null   int64
#  1   self_esteem                   1100 non-null   int64
#  2   mental_health_history         1100 non-null   int64
#  3   depression                    1100 non-null   int64
#  4   headache                      1100 non-null   int64
#  5   blood_pressure                1100 non-null   int64
#  6   sleep_quality                 1100 non-null   int64
#  7   breathing_problem             1100 non-null   int64
#  8   noise_level                   1100 non-null   int64
#  9   living_conditions             1100 non-null   int64
#  10  safety                        1100 non-null   int64
#  11  basic_needs                   1100 non-null   int64
#  12  academic_performance          1100 non-null   int64
#  13  study_load                    1100 non-null   int64
#  14  teacher_student_relationship  1100 non-null   int64
#  15  future_career_concerns        1100 non-null   int64
#  16  social_support                1100 non-null   int64
#  17  peer_pressure                 1100 non-null   int64
#  18  extracurricular_activities    1100 non-null   int64
#  19  bullying                      1100 non-null   int64
#  20  stress_level                  1100 non-null   int64
# dtypes: int64(21)
# memory usage: 180.6 KB

# %% [markdown]
# As we can see, this dataset is composed by 1100 rows (students) and 21 columns of numeric types.

# %% [markdown]
# # Data exploration

# %%
# Statistical information for numeric columns 
data.describe().round(2)
# Out:
#        anxiety_level  self_esteem  mental_health_history  depression  \
# count        1100.00      1100.00                1100.00     1100.00
# mean           11.06        17.78                   0.49       12.56
# std             6.12         8.94                   0.50        7.73
# min             0.00         0.00                   0.00        0.00
# 25%             6.00        11.00                   0.00        6.00
# 50%            11.00        19.00                   0.00       12.00
# 75%            16.00        26.00                   1.00       19.00
# max            21.00        30.00                   1.00       27.00
#
#        headache  blood_pressure  sleep_quality  breathing_problem  \
# count   1100.00         1100.00        1100.00            1100.00
# mean       2.51            2.18           2.66               2.75
# std        1.41            0.83           1.55               1.40
# min        0.00            1.00           0.00               0.00
# 25%        1.00            1.00           1.00               2.00
# 50%        3.00            2.00           2.50               3.00
# 75%        3.00            3.00           4.00               4.00
# max        5.00            3.00           5.00               5.00
#
#        noise_level  living_conditions  ...  basic_needs  academic_performance  \
# count      1100.00            1100.00  ...      1100.00               1100.00
# mean          2.65               2.52  ...         2.77                  2.77
# std           1.33               1.12  ...         1.43                  1.41
# min           0.00               0.00  ...         0.00                  0.00
# 25%           2.00               2.00  ...         2.00                  2.00
# 50%           3.00               2.00  ...         3.00                  2.00
# 75%           3.00               3.00  ...         4.00                  4.00
# max           5.00               5.00  ...         5.00                  5.00
#
#        study_load  teacher_student_relationship  future_career_concerns  \
# count     1100.00                       1100.00                 1100.00
# mean         2.62                          2.65                    2.65
# std          1.32                          1.38                    1.53
# min          0.00                          0.00                    0.00
# 25%          2.00                          2.00                    1.00
# 50%          2.00                          2.00                    2.00
# 75%          3.00                          4.00                    4.00
# max          5.00                          5.00                    5.00
#
#        social_support  peer_pressure  extracurricular_activities  bullying  \
# count         1100.00        1100.00                     1100.00   1100.00
# mean             1.88           2.73                        2.77      2.62
# std              1.05           1.43                        1.42      1.53
# min              0.00           0.00                        0.00      0.00
# 25%              1.00           2.00                        2.00      1.00
# 50%              2.00           2.00                        2.50      3.00
# 75%              3.00           4.00                        4.00      4.00
# max              3.00           5.00                        5.00      5.00
#
#        stress_level
# count       1100.00
# mean           1.00
# std            0.82
# min            0.00
# 25%            0.00
# 50%            1.00
# 75%            2.00
# max            2.00
#
# [8 rows x 21 columns]

# %% [markdown]
# The function describe proveide us with statistical information of the numeric columns.

# %%
# Checking for duplicates (lines)
data.duplicated().sum()
# Out:
# 0

# %%
# Checking if we have missing values (cases)
data.isna().sum()
# Out:
# anxiety_level                   0
# self_esteem                     0
# mental_health_history           0
# depression                      0
# headache                        0
# blood_pressure                  0
# sleep_quality                   0
# breathing_problem               0
# noise_level                     0
# living_conditions               0
# safety                          0
# basic_needs                     0
# academic_performance            0
# study_load                      0
# teacher_student_relationship    0
# future_career_concerns          0
# social_support                  0
# peer_pressure                   0
# extracurricular_activities      0
# bullying                        0
# stress_level                    0
# dtype: int64

# %% [markdown]
# This dataset is free from both missing values and duplicates.

# %%
#Data Display
r = 3
c = 7
it = 1
for i in data.columns:
    plt.subplot(r, c, it )#fix 
    if data[i].nunique() > 6:
        sns.kdeplot(data[i])
        plt.grid()
    else:
        sns.countplot(x=data[i])
    it += 1
plt.tight_layout()
plt.show()

# %%
#The number of unique values for each column
print(data.nunique())
# Out:
# anxiety_level                   22
# self_esteem                     31
# mental_health_history            2
# depression                      28
# headache                         6
# blood_pressure                   3
# sleep_quality                    6
# breathing_problem                6
# noise_level                      6
# living_conditions                6
# safety                           6
# basic_needs                      6
# academic_performance             6
# study_load                       6
# teacher_student_relationship     6
# future_career_concerns           6
# social_support                   4
# peer_pressure                    6
# extracurricular_activities       6
# bullying                         6
# stress_level                     3
# dtype: int64

# %% [markdown]
# *Which factor tend to report higher stress level?*

# %%
# Calculate the correlation of every column
correlation_data= data.corr()

# Create a heatmap
plt.figure(figsize=(14, 10))
sns.heatmap(data=correlation_data, annot=True, cmap='coolwarm')
plt.title("What tends to a higher stress level?", fontweight='bold')
plt.show()

# %% [markdown]
# As we can see, anxiety, depression, future career concerns, bullying, and headaches are highly correlated with increased stress levels. This indicates that students reporting higher levels of those factors are more likely to experience elevated stress levels.
#
# Meanwhile, the heatmap reveals a distinct pattern for factors that appear to have a mitigating effect on stress. Students who report good self-esteem, strong social support networks, positive teacher-student relationships, and better sleep quality tend to reflect a lower stress levels.

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Which physiological factor has the most impact on student stress?

# %%
# Filtering the dataset with only physiological factors
physiological_factors = data[['headache', 'blood_pressure', 'sleep_quality', 'breathing_problem', 'stress_level']]

# Calculating correlation 
correlation_physiological = physiological_factors.corr()

# Visualizing heatmap with 
plt.figure(figsize=(10,8))
sns.heatmap(data=correlation_physiological, annot=True, cmap='coolwarm')
plt.title('Physiological factors vs Stress levels')
plt.show()

# %% [markdown]
# Among the physiological factors, headaches has the strongest correlation with stress levels, which means that students experiencing more frequent headaches are more likely to report higher stress levels.
# Breathing problems and blood pressure also display positive correlations with stress, suggesting that these physiological factors can also contribute to stress levels in students.

# %% [markdown]
# On the other side, the data reveals a potentially reassuring trend—students who report experiencing good sleep quality tend to exhibit lower stress levels. This association implies that ensuring students have better sleep quality may contribute to reducing their overall stress levels.
